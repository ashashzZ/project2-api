# %% [markdown]
# # Project 2: Web Scraping and API access

# %%
# !pip install beautifulsoup4

# %% [markdown]
# ## Part 1: Explore the html for Wikipedia articles.

# %% [markdown]
# ### A. Using inspect element, copy the html code for a table.

# %% [markdown]
# <table class="wikitable plainrowheaders">
# <caption>Prime crew
# </caption>
# <tbody><tr>
# <th style="width:150px;"><a href="/wiki/Astronaut_ranks_and_positions" title="Astronaut ranks and positions">Position</a>
# </th>
# <th scope="col" style="width:150px;">Launching astronaut
# </th>
# <th scope="col" style="width:150px;">Landing astronaut
# </th></tr>
# <tr>
# <th scope="row">Commander
# </th>
# <td colspan="1"><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a href="/wiki/United_States" title="United States"><img alt="United States" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" decoding="async" width="23" height="12" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650"></a></span></span> <a href="/wiki/Barry_E._Wilmore" title="Barry E. Wilmore">Barry E. Wilmore</a><br><a href="/wiki/Expedition_71" title="Expedition 71">Expedition 71</a>/<a href="/wiki/Expedition_72" title="Expedition 72">72</a><sup id="cite_ref-Expedition_crew_16-0" class="reference"><a href="#cite_note-Expedition_crew-16"><span class="cite-bracket">[</span>d<span class="cite-bracket">]</span></a></sup><br>Third spaceflight
# </td>
# <td>None
# </td></tr>
# <tr>
# <th scope="row">Pilot
# </th>
# <td colspan="1"><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><a href="/wiki/United_States" title="United States"><img alt="United States" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" decoding="async" width="23" height="12" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650"></a></span></span> <a href="/wiki/Sunita_Williams" title="Sunita Williams">Sunita Williams</a><br>Expedition 71/72<sup id="cite_ref-Expedition_crew_16-1" class="reference"><a href="#cite_note-Expedition_crew-16"><span class="cite-bracket">[</span>d<span class="cite-bracket">]</span></a></sup><br>Third spaceflight
# </td>
# <td>None
# </td></tr>
# </tbody></table>

# %% [markdown]
# ### B. Using inspect element, find the html syntax for a link.

# %% [markdown]
# <a href="/wiki/Michael_Fincke" title="Michael Fincke">Michael Fincke</a>

# %% [markdown]
# ### C. Using inspect element, find the html syntax for linking an image

# %% [markdown]
# <img src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Calypso_Starliner_capsule_postflight.jpg/220px-Calypso_Starliner_capsule_postflight.jpg" decoding="async" width="220" height="147" class="mw-file-element" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Calypso_Starliner_capsule_postflight.jpg/330px-Calypso_Starliner_capsule_postflight.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Calypso_Starliner_capsule_postflight.jpg/440px-Calypso_Starliner_capsule_postflight.jpg 2x" data-file-width="6720" data-file-height="4480">

# %% [markdown]
# ## Part 2: Explore one Wikipedia page with the beautifulsoup package

# %%
import bs4
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#save and print the text content of a page with all tags removed
url = 'https://en.wikipedia.org/wiki/Boeing_Crew_Flight_Test'
page = requests.get(url)
soup = bs4.BeautifulSoup(page.content, 'html.parser')
text = soup.get_text()
print(text)
# Out:
# Boeing Crew Flight Test - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Appearance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
#  Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1
# Delays
#
#
#
#
#
#
#
#
# 2
# Capsule
#
#
#
#
#
#
#
#
# 3
# Crew
#
#
#
#
#
#
#
#
# 4
# Mission
#
#
#
#
# Toggle Mission subsection
#
#
# ...

# %%
#download an image with beautifulsoup and save it in this repository
url = 'https://nickjr.fandom.com/wiki/Peppa_Pig_(character)'
page = requests.get(url)
soup = bs4.BeautifulSoup(page.content, 'html.parser')
image_tag = soup.find('img')
image_tag = soup.find('img')
if image_tag:
    image_url = image_tag['src']
    if image_url.startswith('//'):
        image_url = 'https:' + image_url
    elif image_url.startswith('/'):
        image_url = 'https://nickjr.fandom.com/wiki/Peppa_Pig_(character)' + image_url
    response = requests.get(image_url)
    if response.status_code == 200:
        filename = 'random.jpg'
        with open(filename, 'wb') as f:
            f.write(response.content)

# %%
#find all the links in a page with beautifulsoup
#print the first 100 characters of ten of these links
url = 'https://www.peppapig.com/en-us'
page = requests.get(url)
soup = bs4.BeautifulSoup(page.content, 'html.parser')

links = soup.find_all('a', href=True)

for i, link in enumerate(links[:10], 1):
    link_href = str(link.get('href'))[:100]
    print(f"Link {i}: {link_href}")
# Out:
# Link 1: /en-us
# Link 2: https://shop.hasbro.com/en-us/peppa-pig/apps
# Link 3: /en-us/characters
# Link 4: /en-us/activities
# Link 5: https://shop.hasbro.com/en-us/all-products?brand=peppa-pig
# Link 6: https://www.youtube.com//user/theofficialpeppa
# Link 7: https://www.instagram.com/officialpeppa/
# Link 8: https://twitter.com/peppapig
# Link 9: https://www.facebook.com/OfficialPeppaPig
# Link 10: /worldwide

# %% [markdown]
# ## Part 3: Downloading scripts

# %%
scripts=pd.read_csv('pudding_data.csv')

# %%
scripts
# Out:
#         imdb_id  script_id             title  year  \
# 0     tt0019777       4031     The Cocoanuts  1929
# 1     tt0021884       8521      Frankenstein  1931
# 2     tt0022054       1086   The Last Flight  1931
# 3     tt0022626       1631  American Madness  1932
# 4     tt0022958       2438       Grand Hotel  1932
# ...         ...        ...               ...   ...
# 1995  tt3733778       8533     Pay the Ghost  2015
# 1996  tt3808342       5499       Son of Saul  2015
# 1997  tt3850214       8056              Dope  2015
# 1998  tt3859076       5507             Truth  2015
# 1999  tt4270516       5410           Grandma  2015
#
#       gross (inflation-adjusted)  \
# 0                            NaN
# 1                          298.0
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                         NaN
# 1996                         0.0
# 1997                        18.0
# ...

# %%
#using the links in the "link" column, download the first 1000 characters of each script
#use requests and bs4, remember to remove all html tags

def get_chars(link):
    try:
        response = requests.get(link, timeout=10)
        soup = BeautifulSoup(response.content, 'html.parser')
        text = soup.get_text()
        return text[:1000]
    except Exception as e:
        return str(e)

# %%
#add a new column to the df with the text downloaded
#save this new dataframe as "pudding_texts.csv"
scripts['Part3'] = scripts['link'].apply(get_chars)
scripts.to_csv('pudding_texts.csv', index=False)
scripts
# Out:
#         imdb_id  script_id             title  year  \
# 0     tt0019777       4031     The Cocoanuts  1929
# 1     tt0021884       8521      Frankenstein  1931
# 2     tt0022054       1086   The Last Flight  1931
# 3     tt0022626       1631  American Madness  1932
# 4     tt0022958       2438       Grand Hotel  1932
# ...         ...        ...               ...   ...
# 1995  tt3733778       8533     Pay the Ghost  2015
# 1996  tt3808342       5499       Son of Saul  2015
# 1997  tt3850214       8056              Dope  2015
# 1998  tt3859076       5507             Truth  2015
# 1999  tt4270516       5410           Grandma  2015
#
#       gross (inflation-adjusted)  \
# 0                            NaN
# 1                          298.0
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                         NaN
# 1996                         0.0
# 1997                        18.0
# ...

# %% [markdown]
# ## Part 4: TMDB database

# %% [markdown]
# #### Browse the documentation at https://developer.themoviedb.org/reference/intro/getting-started. Create an account to authenticate

# %%
#create a dataset of the movies in theaters now. Include metadata fields you are interested in. 
import requests
import os
from PIL import Image
from io import BytesIO

API_KEY = '29d895ced183fd0434492c38f661485a'
BASE_URL = 'https://api.themoviedb.org/3'

def get_now_playing_movies(api_key):
    url = f'{BASE_URL}/movie/now_playing'
    params = {
        'api_key': api_key,
        'language': 'en-US',
        'page': 1
    }
    response = requests.get(url, params=params)
    data = response.json()
    return data['results']

def download_movie_poster(movie, save_dir):
    poster_path = movie.get('poster_path')
    if poster_path:
        poster_url = f'https://image.tmdb.org/t/p/w500{poster_path}'
        response = requests.get(poster_url)
        img = Image.open(BytesIO(response.content))
        img.save(os.path.join(save_dir, f"{movie['title']}.jpg"))

save_directory = 'movie_posters'
if not os.path.exists(save_directory):
    os.makedirs(save_directory)

movies = get_now_playing_movies(API_KEY)

for movie in movies[:10]:
    download_movie_poster(movie, save_directory)
    print(f"Downloaded poster for {movie['title']}")

for movie in movies[:10]:
    print(f"Title: {movie['title']}, Release Date: {movie['release_date']}, Rating: {movie['vote_average']}")
# Out:
# Downloaded poster for The Crow
# Downloaded poster for It Ends with Us
# Downloaded poster for Despicable Me 4
# Downloaded poster for Borderlands
# Downloaded poster for The Substance
# Downloaded poster for Blink Twice
# Downloaded poster for Beetlejuice Beetlejuice
# Downloaded poster for Officer Black Belt
# Downloaded poster for Outlaw
# Downloaded poster for Rebel Ridge
# Title: The Crow, Release Date: 2024-08-21, Rating: 5.451
# Title: It Ends with Us, Release Date: 2024-08-07, Rating: 6.905
# Title: Despicable Me 4, Release Date: 2024-06-20, Rating: 7.164
# Title: Borderlands, Release Date: 2024-08-07, Rating: 5.894
# Title: The Substance, Release Date: 2024-09-07, Rating: 7.255
# Title: Blink Twice, Release Date: 2024-08-21, Rating: 6.698
# Title: Beetlejuice Beetlejuice, Release Date: 2024-09-04, Rating: 7.136
# Title: Officer Black Belt, Release Date: 2024-09-10, Rating: 7.886
# Title: Outlaw, Release Date: 2024-06-20, Rating: 6.544
# ...

# %%
#download the movie posters for 10 of these movies and save them to this repository
